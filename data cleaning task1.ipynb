# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
print(os.listdir())
# Out:
# ['.android', '.cache', '.conda', '.condarc', '.continuum', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.spyder-py3', '.vscode', 'anaconda', 'anaconda3', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'data cleaning task.ipynb', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'food_coded.csv', 'IntelGraphicsProfiles', 'Jedi', 'Links', 'Local Settings', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{a2332f18-cdbf-11ec-8680-002248483d79}.TM.blf', 'NTUSER.DAT{a2332f18-cdbf-11ec-8680-002248483d79}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{a2332f18-cdbf-11ec-8680-002248483d79}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'PrintHood', 'python practice.ipynb', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Videos']

# %%
df=pd.read_csv("food_coded.csv")

# %%
df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
df.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         21
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
sns.heatmap(df.isnull(), yticklabels=False)
# Out:
# <Axes: >

# %%
df.fillna(method='ffill')
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           2.0           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           4.0           315.0
#
# ...

# %%
df.interpolate()
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           3.0           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           4.0           315.0
#
# ...

# %%
df_dropped=df.dropna(how="all")

# %%
df_dropped
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
df1=df.fillna({
    'calories_day':3,'cuisine':1, 'employment':2, 'exercise':1, 'fav_food':1, 'income':5, 'life_rewarding':9, 'on_off_campus':1,
    'sports':1,'comfort_food_reasons_coded':2, 'type_sports':"volleyball",'weight':158, 'cook':2
    
})
df1
# Out:
#             GPA  Gender  breakfast  calories_chicken  calories_day  \
# 0           2.4       2          1               430           3.0
# 1         3.654       1          1               610           3.0
# 2           3.3       1          1               720           4.0
# 3           3.2       1          1               430           3.0
# 4           3.5       1          1               720           2.0
# 5          2.25       1          1               610           3.0
# 6           3.8       2          1               610           3.0
# 7           3.3       1          1               720           3.0
# 8           3.3       1          1               430           3.0
# 9           3.3       1          1               430           3.0
# 10          3.5       1          1               610           3.0
# 11        3.904       1          1               720           4.0
# 12          3.4       2          1               430           3.0
# ...

# %%
missing_values=["none",np.nan]
df=pd.read_csv("food_coded.csv", na_values=missing_values)
missing_values
# Out:
# ['none', nan]

# %%
sns.heatmap(df1.isnull(), yticklabels=False)
# Out:
# <Axes: >

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['GPA'].duplicated().sum()
# Out:
# 86

# %%
df[df['GPA'].duplicated()].head(2)
# Out:
#    GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 7  3.3       1          1               720           3.0           420.0
# 8  3.3       1          1               430           NaN           420.0
#
#    coffee                      comfort_food  \
# 7       1  Ice cream, cheeseburgers, chips.
# 8       1          Donuts, ice cream, chips
#
#                                 comfort_food_reasons  \
# 7  I eat comfort food when im stressed out from s...
# 8                                           Boredom
#
#    comfort_food_reasons_coded  ...  soup  sports  thai_food tortilla_calories  \
# 7                         1.0  ...   1.0     2.0          1             725.0
# 8                         2.0  ...   2.0     2.0          5             725.0
#
#    turkey_calories  type_sports veggies_day  vitamins  waffle_calories  weight
# 7              500          NaN           4         2             1315     137
# ...

# %%
df1.shape
# Out:
# (125, 61)

# %%
pd.set_option('display.max_columns',61)

# %%
df1.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           3.0           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                               NaN       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  cook  comfort_food_reasons_coded.1  cuisine  \
# ...

# %% [markdown]
# df1.head()

# %%
pd.set_option('display.max_rows', 125, 'display.max_columns', 61)
df1
# Out:
#             GPA  Gender  breakfast  calories_chicken  calories_day  \
# 0           2.4       2          1               430           3.0
# 1         3.654       1          1               610           3.0
# 2           3.3       1          1               720           4.0
# 3           3.2       1          1               430           3.0
# 4           3.5       1          1               720           2.0
# 5          2.25       1          1               610           3.0
# 6           3.8       2          1               610           3.0
# 7           3.3       1          1               720           3.0
# 8           3.3       1          1               430           3.0
# 9           3.3       1          1               430           3.0
# 10          3.5       1          1               610           3.0
# 11        3.904       1          1               720           4.0
# 12          3.4       2          1               430           3.0
# ...
